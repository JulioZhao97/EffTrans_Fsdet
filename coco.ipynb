# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2'

# !PORT=29500 ./tools/detection/dist_train.sh configs/detection/tfa/coco/tfa_r101_fpn_coco_30shot-fine-tuning-test-distill.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# fatal: Not a git repository (or any parent up to mount point /data)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: Not a git repository (or any parent up to mount point /data)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-03-16 09:53:19,985 - mmfewshot - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.11 (default, Jul 27 2021, 14:32:16) [GCC 7.5.0]
# CUDA available: True
# GPU 0,1,2: GeForce RTX 2080 Ti
# CUDA_HOME: /usr/local/cuda
# NVCC: Cuda compilation tools, release 10.0, V10.0.130
# ...

# %%
anno_all = {}
for i, image in enumerate(jfile['images']):
    split = image['file_name'].split('_')[1]
    if split in anno_all:
        anno_all[split].append(image['file_name'])
    else:
        anno_all[split] = [image['file_name']]
for k, v in anno_all.items():
    print(k,len(v))
# Out:
# train2014 82081
# val2014 35183

# %%
import os

split = 'val2014'
path = 'data/coco/{}'.format(split)
img_real = os.listdir(path)
for img in anno_all[split]:
    if img not in img_real:
        print(img)
