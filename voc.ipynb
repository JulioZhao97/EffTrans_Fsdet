# %% [markdown]
# <font size=10>faster-rcnn</font>

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3'
#os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# !PORT=29500 ./tools/detection/dist_train.sh configs/detection/faster-rcnn/voc/split1/frcn_r101_fpn_tb-split1_1shot-fine-tuning.py 4
#%run tools/detection/train.py configs/detection/tfa/tb/split1/tfa_r101_fpn_tb-split1_1shot-fine-tuning-1e-4-task0.py
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# ...

# %% [markdown]
# <font size=10>TFA</font>

# %% [markdown]
# <font size=10>step1 : base training</font>

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3'

# !PORT=29500 ./tools/detection/dist_train.sh configs/detection/tfa/voc/split1/tfa_r101_fpn_voc-split1_base-training-dummy.py 4
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# fatal: Not a git repository (or any parent up to mount point /data)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: Not a git repository (or any parent up to mount point /data)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: Not a git repository (or any parent up to mount point /data)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: Not a git repository (or any parent up to mount point /data)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-02-10 17:17:01,937 - mmfewshot - INFO - Environment info:
# ...

# %% [markdown]
# <font size=10>step2 : bbox reshape</font>

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '4'

# !python -m tools.detection.misc.initialize_bbox_head \
    --src1 work_dirs/voc/tfa/split1/tfa_r101_fpn_voc-split1_base-training/latest.pth \
    --method random_init \
    --save-dir work_dirs/voc/tfa/split1/tfa_r101_fpn_voc-split1_base-training-test
# Out:
# <class 'collections.OrderedDict'>
# backbone.conv1.weight torch.Size([64, 3, 7, 7])
# backbone.bn1.weight torch.Size([64])
# backbone.bn1.bias torch.Size([64])
# backbone.bn1.running_mean torch.Size([64])
# backbone.bn1.running_var torch.Size([64])
# backbone.bn1.num_batches_tracked torch.Size([])
# backbone.layer1.0.conv1.weight torch.Size([64, 64, 1, 1])
# backbone.layer1.0.bn1.weight torch.Size([64])
# backbone.layer1.0.bn1.bias torch.Size([64])
# backbone.layer1.0.bn1.running_mean torch.Size([64])
# backbone.layer1.0.bn1.running_var torch.Size([64])
# backbone.layer1.0.bn1.num_batches_tracked torch.Size([])
# backbone.layer1.0.conv2.weight torch.Size([64, 64, 3, 3])
# backbone.layer1.0.bn2.weight torch.Size([64])
# backbone.layer1.0.bn2.bias torch.Size([64])
# backbone.layer1.0.bn2.running_mean torch.Size([64])
# backbone.layer1.0.bn2.running_var torch.Size([64])
# backbone.layer1.0.bn2.num_batches_tracked torch.Size([])
# ...

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'
#os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3'

#!PORT=29501 ./tools/detection/dist_train.sh configs/detection/tfa/voc/split1/tfa_r101_fpn_voc-split1_5shot-fine-tuning.py 4
# %run tools/detection/train.py configs/detection/tfa/voc/split1/tfa_r101_fpn_voc-split1_5shot-fine-tuning-my.py
# Out:
# fatal: Not a git repository (or any parent up to mount point /data)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-02-12 17:12:24,553 - mmfewshot - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.11 (default, Jul 27 2021, 14:32:16) [GCC 7.5.0]
# CUDA available: True
# GPU 0: GeForce RTX 2080 Ti
# CUDA_HOME: /usr/local/cuda
# NVCC: Cuda compilation tools, release 10.0, V10.0.130
# GCC: gcc (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609
# PyTorch: 1.7.0
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v1.6.0 (Git Hash 5ef631a030a6f73131c77892041042805a06064f)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 10.1
# ...

# %% [markdown]
# <font size=10>meta-rcnn</font>

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3'

# !PORT=29500 ./tools/detection/dist_train.sh configs/detection/meta_rcnn/voc/split1/meta-rcnn_r101_c4_8xb4_voc-split1_base-training.py 4
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# ...

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3'

# !PORT=29500 ./tools/detection/dist_train.sh configs/detection/meta_rcnn/voc/split1/meta-rcnn_r101_c4_8xb4_voc-split1_1shot-fine-tuning.py 4
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# ...

# %% [markdown]
# <font size=10>attention rpn</font>

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3'

# !PORT=29500 ./tools/detection/dist_train.sh configs/detection/attention_rpn/voc/split1/attention-rpn_r50_c4_voc-split1_base-training.py 4
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2021-12-14 09:06:38,194 - mmfewshot - INFO - Environment info:
# ...

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3'

# !PORT=29500 ./tools/detection/dist_train.sh configs/detection/attention_rpn/voc/split1/attention-rpn_r50_c4_voc-split1_1shot-fine-tuning.py 4
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# ...

# %% [markdown]
# <font size=10>fsdet</font>

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3'

# !PORT=29500 ./tools/detection/dist_train.sh configs/detection/fsdetview/voc/split1/fsdetview_r101_c4_8xb4_voc-split1_base-training.py 4
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2021-12-15 07:57:47,083 - mmfewshot - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.11 (default, Jul 27 2021, 14:32:16) [GCC 7.5.0]
# CUDA available: True
# ...

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3'

# !PORT=29500 ./tools/detection/dist_train.sh configs/detection/fsdetview/voc/split1/fsdetview_r101_c4_8xb4_voc-split1_1shot-fine-tuning.py 4
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# libibverbs: Warning: couldn't open config directory '/etc/libibverbs.d'.
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: Not a git repository (or any parent up to mount point /opt/data/nfs)
# ...
