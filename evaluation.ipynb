# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %run ./tools/detection/test.py \
  configs/detection/tfa/tb/split1/10shot/task0/tfa_r101_fpn_tb-split1_10shot-fine-tuning-my-ema.py \
  ./work_dirs/tb/split1/10shot/task0/tfa_r101_fpn_tb-split1_10shot-fine-tuning-my-ema/best.pth --eval mAP
# Out:
# 2022-04-22 09:10:26,691 - mmfewshot - INFO -
# FewShotVOCDatasetTB Test dataset with number of images 3000, and instance counts:
# +--------------------------+-------+-----------------------+-------+--------------------------+-------+------------------------+-------+---------------+-------+
# | category                 | count | category              | count | category                 | count | category               | count | category      | count |
# +--------------------------+-------+-----------------------+-------+--------------------------+-------+------------------------+-------+---------------+-------+
# | 0 [014-VOA]              | 200   | 1 [015-DWTV]          | 200   | 2 [002-beijingweishi]    | 200   | 3 [008-shenzhenweishi] | 200   | 4 [016-CBS]   | 200   |
# | 5 [006-henanweishi]      | 200   | 6 [003-tianjinweishi] | 200   | 7 [005-shandongweishi]   | 200   | 8 [019-TVBS]           | 200   | 9 [001-CCTV1] | 200   |
# ...

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %run ./tools/detection/test.py \
  configs/detection/tfa/tb/split1/10shot/task0/tfa_r101_fpn_tb-split1_10shot-fine-tuning-my-ema-distill.py \
  ./work_dirs/tb/split1/10shot/task0/tfa_r101_fpn_tb-split1_10shot-fine-tuning-my-ema-distill/best.pth --eval mAP
# Out:
# 2022-04-22 09:17:51,859 - mmfewshot - INFO -
# FewShotVOCDatasetTB Test dataset with number of images 3000, and instance counts:
# +--------------------------+-------+-----------------------+-------+--------------------------+-------+------------------------+-------+---------------+-------+
# | category                 | count | category              | count | category                 | count | category               | count | category      | count |
# +--------------------------+-------+-----------------------+-------+--------------------------+-------+------------------------+-------+---------------+-------+
# | 0 [014-VOA]              | 200   | 1 [015-DWTV]          | 200   | 2 [002-beijingweishi]    | 200   | 3 [008-shenzhenweishi] | 200   | 4 [016-CBS]   | 200   |
# | 5 [006-henanweishi]      | 200   | 6 [003-tianjinweishi] | 200   | 7 [005-shandongweishi]   | 200   | 8 [019-TVBS]           | 200   | 9 [001-CCTV1] | 200   |
# ...
